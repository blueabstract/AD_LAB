# %%
#series using array
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series(dtype='object')
print("Pandas Series: ", ser)
# simple array
data = np.array(['s', 'e', 'r', 'i', 'e', 's'])
ser = pd.Series(data)
print("Pandas Series:\n", ser)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    s
# 1    e
# 2    r
# 3    i
# 4    e
# 5    s
# dtype: object

# %%
#series using dictionary
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series(dtype='object')
print("Pandas Series: ", ser)
# simple dictionary
data={1:'s', 2:'e', 3:'r', 4:'i', 5:'e', 6:'s'}
ser=pd.Series(data)
print("Pandas Series:\n", ser)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  1    s
# 2    e
# 3    r
# 4    i
# 5    e
# 6    s
# dtype: object

# %%
#series using scalar values
import pandas as pd
import numpy as np
# Creating empty series
ser = pd.Series(dtype='object')
print("Pandas Series: ", ser)
ser=pd.Series(4, index=[1,2,3,4])
print("Pandas Series:\n", ser)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  1    4
# 2    4
# 3    4
# 4    4
# dtype: int64

# %%
x=pd.Series([1,2,3],index=['a','b','c'])
print(x.shape)
print(x.size)
print(x.index)
print(x.ndim)
print(x.values)
print(x.dtypes)
print(x.nbytes)
print(x.empty)
print(x.hasnans)
# Out:
# (3,)
# 3
# Index(['a', 'b', 'c'], dtype='object')
# 1
# [1 2 3]
# int64
# 24
# False
# False

# %%
x=pd.Series([1,2,3],index=['a','b','c'])
x
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# importing the module
import pandas as pd
# creating a sample dataframe
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
'Mahindra', 'Maruti', 'Hyundai',
'Renault', 'Tata', 'Maruti'],
'Year': [2012, 2014, 2011, 2015, 2012,
2016, 2014, 2018, 2019],
'Kms Driven': [50000, 30000, 60000,
25000, 10000, 46000,
31000, 15000, 12000],
'City': ['Gurgaon', 'Delhi', 'Mumbai',
'Delhi', 'Mumbai', 'Delhi',
'Mumbai', 'Chennai', 'Ghaziabad'],

'Mileage': [28, 27, 25, 26, 28,
29, 24, 21, 24]})

# displaying the DataFrame
display(data)
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1   Hyundai  2014       30000      Delhi       27
# 2      Tata  2011       60000     Mumbai       25
# 3  Mahindra  2015       25000      Delhi       26
# 4    Maruti  2012       10000     Mumbai       28
# 5   Hyundai  2016       46000      Delhi       29
# 6   Renault  2014       31000     Mumbai       24
# 7      Tata  2018       15000    Chennai       21
# 8    Maruti  2019       12000  Ghaziabad       24

# %%
#Display the first row
data.loc[2]
# Out:
# Brand           Tata
# Year            2011
# Kms Driven     60000
# City          Mumbai
# Mileage           25
# Name: 2, dtype: object

# %%
#Display Brand of first row
data.loc[2,'Year']
# Out:
# np.int64(2011)

# %%
#Display 1st, 2nd and 4th rows
data.loc[[0,1,4]]
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 0   Maruti  2012       50000  Gurgaon       28
# 1  Hyundai  2014       30000    Delhi       27
# 4   Maruti  2012       10000   Mumbai       28

# %%
#Display City of 1st and 2nd row
data.loc[[0,1],'City']
# Out:
# 0    Gurgaon
# 1      Delhi
# Name: City, dtype: object

# %%
#Display 2nd row to 5th row
data.loc[1:5]
# Out:
#       Brand  Year  Kms Driven    City  Mileage
# 1   Hyundai  2014       30000   Delhi       27
# 2      Tata  2011       60000  Mumbai       25
# 3  Mahindra  2015       25000   Delhi       26
# 4    Maruti  2012       10000  Mumbai       28
# 5   Hyundai  2016       46000   Delhi       29

# %%
# Select the first row
row = data.iloc[0] # Select the first row
row
# Out:
# Brand          Maruti
# Year             2012
# Kms Driven      50000
# City          Gurgaon
# Mileage            28
# Name: 0, dtype: object

# %%
# Select first and third rows by position
rows = data.iloc[[0, 2]]
rows
# Out:
#     Brand  Year  Kms Driven     City  Mileage
# 0  Maruti  2012       50000  Gurgaon       28
# 2    Tata  2011       60000   Mumbai       25

# %%
#Select first and 3rd rows (Second column value only)
d=data.iloc[[0,2],[1]]
d
# Out:
#    Year
# 0  2012
# 2  2011

# %%
import pandas as pd
data = {
"calories": [420, 380, 390],
"duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
import pandas as pd
df=pd.read_csv("/content/Iris_data_sample.csv")
df
# Out:
#      Unnamed: 0 SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm  \
# 0             1           5.1           3.5           1.4           0.2
# 1             2           4.9           NaN           1.4           0.2
# 2             3           4.7           3.2           1.3           0.2
# 3             4            ??           3.1           1.5           0.2
# 4             5             5           3.6           ###           0.2
# ..          ...           ...           ...           ...           ...
# 145         146           6.7           3.0           5.2           2.3
# 146         147           6.3           2.5             5           1.9
# 147         148           6.5           3.0           5.2           2.0
# 148         149           6.2           3.4           5.4           2.3
# 149         150           5.9           3.0           5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1               NaN
# 2       Iris-setosa
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/Iris_data_sample.csv",index_col=0)
df
# Out:
#     SepalLengthCm  SepalWidthCm PetalLengthCm  PetalWidthCm         Species
# 1             5.1           3.5           1.4           0.2     Iris-setosa
# 2             4.9           NaN           1.4           0.2             NaN
# 3             4.7           3.2           1.3           0.2     Iris-setosa
# 4              ??           3.1           1.5           0.2     Iris-setosa
# 5               5           3.6           ###           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 146           6.7           3.0           5.2           2.3  Iris-virginica
# 147           6.3           2.5             5           1.9  Iris-virginica
# 148           6.5           3.0           5.2           2.0  Iris-virginica
# 149           6.2           3.4           5.4           2.3  Iris-virginica
# 150           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Junk values can be converted to missing values by passing them as a list to the parameter ‘n
import pandas as pd
df=pd.read_csv("/content/Iris_data_sample.csv",index_col=0,na_values=['??','###'])
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           NaN            1.4           0.2             NaN
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              NaN           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            NaN           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  149 non-null    float64
#  1   SepalWidthCm   149 non-null    float64
#  2   PetalLengthCm  148 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     149.000000    149.000000     148.000000    150.000000
# mean        5.851678      3.054362       3.788514      1.198667
# std         0.824507      0.435034       1.757260      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.400000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **DATA PREPROCESSING**

# %% [markdown]
# 1.Data Cleaning

# %% [markdown]
# Filling missing Values

# %%
df.isnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1            False         False          False         False    False
# 2            False          True          False         False     True
# 3            False         False          False         False    False
# 4             True         False          False         False    False
# 5            False         False           True         False    False
# ..             ...           ...            ...           ...      ...
# 146          False         False          False         False    False
# 147          False         False          False         False    False
# 148          False         False          False         False    False
# 149          False         False          False         False    False
# 150          False         False          False         False    False
#
# [150 rows x 5 columns]

# %%
df.notnull()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1             True          True           True          True     True
# 2             True         False           True          True    False
# 3             True          True           True          True     True
# 4            False          True           True          True     True
# 5             True          True          False          True     True
# ..             ...           ...            ...           ...      ...
# 146           True          True           True          True     True
# 147           True          True           True          True     True
# 148           True          True           True          True     True
# 149           True          True           True          True     True
# 150           True          True           True          True     True
#
# [150 rows x 5 columns]

# %%
df1=df.fillna(0)
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           0.0            1.4           0.2               0
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              0.0           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            0.0           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **matplotlib.pyplot.hist()**

# %%
import matplotlib.pyplot as plt
plt.hist(df['SepalLengthCm'], color='red',edgecolor='white',bins=5)
plt.title('Histogram of SepalLength')
plt.xlabel('SepalLengthCm')
plt.ylabel('Frequency')

print("Subarno Shome")
print("2330345")
# Out:
# Subarno Shome
# 2330345

# %%
import matplotlib.pyplot as plt
plt.hist(df['PetalLengthCm'], color='orange',edgecolor='white',bins=5)
plt.title('Histogram of PetalLength')
plt.xlabel('PetalLengthCm')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df['SepalWidthCm'], color='red',edgecolor='white',bins=5)
plt.title('Histogram of SepalWidth')
plt.xlabel('SepalWidthCm')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt
plt.hist(df['PetalWidthCm'], color='pink',edgecolor='white',bins=5)
plt.title('Histogram of PetalWidth')
plt.xlabel('PetalWidthCm')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import matplotlib.pyplot as plt

# Get the counts of each species
species_counts = df['Species'].value_counts()

# Create a bar plot instead of a histogram for categorical data
plt.figure(figsize=(8, 6))
species_counts.plot(kind='bar', color='grey', edgecolor='white')
plt.title('Distribution of Species')
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.set()
sns.scatterplot(x='SepalLengthCm',y='Species',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %%
sns.scatterplot(x='PetalLengthCm',y='Species',data=df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Species'>

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalWidthCm',y='PetalWidthCm',data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='PetalWidthCm'>

# %%
sns.scatterplot(x='PetalWidthCm',y='PetalLengthCm',data=df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='PetalLengthCm'>

# %%
sns.scatterplot(x='SepalWidthCm',y='SepalLengthCm',data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>

# %%
#Plot heatmap of correlation matrix
sns.heatmap(data=df[['SepalLengthCm','SepalWidthCm',

'PetalLengthCm','PetalWidthCm']].corr(),
annot=True, linecolor='white', linewidths=0.25, cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# **Encoding Categorical Data**

# %%
#Label Encoder
from sklearn.preprocessing import LabelEncoder
data = ['red', 'blue', 'green', 'blue', 'red']
label_encoder = LabelEncoder()
encoded_data = label_encoder.fit_transform(data)
print(encoded_data)
# Out:
# [2 0 1 0 2]

# %%
#OneHot Encoder
from sklearn.preprocessing import OneHotEncoder
import numpy as np
# Sample data
data = np.array(['red', 'blue', 'green', 'blue', 'red']).reshape(-1, 1)
# Initialize OneHotEncoder
onehot_encoder = OneHotEncoder(sparse_output=False)
# Fit and transform the data
encoded_data = onehot_encoder.fit_transform(data)
print(encoded_data)
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [1. 0. 0.]
#  [0. 0. 1.]]

# %%
from sklearn.preprocessing import OrdinalEncoder
# Sample data
data = np.array(['low', 'medium', 'high', 'medium', 'low']).reshape(-1, 1)
# Initialize OrdinalEncoder
ordinal_encoder = OrdinalEncoder(categories=[['low', 'medium', 'high']])
# Fit and transform the data
encoded_data = ordinal_encoder.fit_transform(data)
print(encoded_data)
# Out:
# [[0.]
#  [1.]
#  [2.]
#  [1.]
#  [0.]]
