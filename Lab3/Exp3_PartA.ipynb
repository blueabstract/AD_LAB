# %% [markdown]
# **Step 1: Install Required Libraries**

# %%
# !pip install PyPDF2 beautifulsoup4 requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 10.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Step 2: Import Libraries and Define PDF Reader**

# %%
import PyPDF2
def read_pdf(file_path):
  text = ""
  with open(file_path, "rb") as file:
    reader = PyPDF2.PdfReader(file)
    for page in reader.pages:
      text += page.extract_text()
  return text

# %% [markdown]
# **Step 3: Define Web Scraper Function**

# %%
import requests

from bs4 import BeautifulSoup
def scrape_website(url):
  response = requests.get(url)
  soup = BeautifulSoup(response.text, "html.parser")
  paragraphs = soup.find_all("p")
  text = " ".join([p.get_text() for p in paragraphs])
  return text

# %% [markdown]
# **Step 4: Define Keyword Extraction**

# %%
def extract_keywords(question):
  stopwords = ["how", "to", "is", "the", "a", "an", "of", "for", "in", "on"]
  words = question.lower().split()
  keywords = [word for word in words if word not in stopwords]
  return keywords

# %% [markdown]
# **Step 5: Create Chatbot Logic**

# %%
def chatbot_response(question, pdf_text, web_text):
    keywords = extract_keywords(question)

    # Search in PDF text
    for line in pdf_text.split("\n"):
        line_lower = line.lower()
        for keyword in keywords:
            if keyword in line_lower:
                return "ChatBot (From PDF):\n" + line.strip()

    # Search in web text
    for line in web_text.split("."):
        line_lower = line.lower()
        for keyword in keywords:
            if keyword in line_lower:
                return "ChatBot (From Website):\n" + line.strip()

    return "Sorry, no relevant instruction found."

# %% [markdown]
# **Step 6: Load Content and Start Chatbot**

# %%
# Assuming you have these functions defined earlier
pdf_text = read_pdf("/EPRS_BRI(2021)698792_EN.pdf")
web_text = scrape_website("https://en.wikipedia.org/wiki/Artificial_intelligence")

print("Chatbot is ready. Type 'exit' to quit.")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = chatbot_response(user_input, pdf_text, web_text)
    print("Bot:", response)
# Out:
# Chatbot is ready. Type 'exit' to quit.
# You: hi
# Bot: ChatBot (From PDF):
# to a 'risk -based approach'. Some AI systems presenting 'unacceptable' risks are prohibited. A wide
# You: what is ai
# Bot: ChatBot (From PDF):
# European Union lawmakers signed  the artificial intelligence (AI) act in  June 2024. The AI act, the first
# You: AI
# Bot: ChatBot (From PDF):
# European Union lawmakers signed  the artificial intelligence (AI) act in  June 2024. The AI act, the first
# You: DANCE
# Bot: ChatBot (From PDF):
# Furthermore, guidance would be desirable  on how to ensure compliance with transparency and
# You: exit
