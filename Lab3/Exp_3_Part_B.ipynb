# %%
# !pip install google-generativeai requests beautifulsoup4 pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.6/329.6 kB 25.5 MB/s eta 0:00:00
# ...

# %%
import os
import google.generativeai as genai
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **Configure API key**

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyASfhOZW96sRqTpZLTFXtjajPFl_z0jWH8"
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %% [markdown]
# **Define Web Scraping and PDF Reading Functions**

# %%
import requests
from bs4 import BeautifulSoup
from pypdf import PdfReader

def scrape_website(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    paragraphs = soup.find_all("p")
    text = " ".join([p.get_text() for p in paragraphs])
    return text

def read_pdf(file_path):
    text = ""
    reader = PdfReader(file_path)
    for page in reader.pages:
        if page.extract_text():
            text += page.extract_text() + "\n"
    return text

# %% [markdown]
# **Create AI Chatbot Logic**

# %%
def ai_answer(question, manual_text, web_text):
    model = genai.GenerativeModel("gemini-2.5-flash")
    prompt = f"""
You are an assistant.
Use ONLY the following text to answer the question.
If the answer is not present in the text, say:
"This information is not available."

PDF Text:
{manual_text}

Online Text:
{web_text}

Question:
{question}

Answer clearly in simple steps.
"""
    response = model.generate_content(prompt)
    return response.text.strip()

# %% [markdown]
# **Load Content and Start AI Chatbot**

# %%
web_text = scrape_website("https://en.wikipedia.org/wiki/Python_(programming_language)")
manual_text = read_pdf("/Tutorial_EDIT.pdf")  # Update this path

print("Help Bot is ready.")
print("Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    reply = ai_answer(user_input, manual_text, web_text)
    print("\nBot:", reply, "\n")
# Out:
# Help Bot is ready.
# Type 'exit' to quit.
#
# You: hi
#
# Bot: This information is not available.
#
# You: what is python?
#
# Bot: Python is an easy to learn, powerful programming language. It has efficient high-level data structures and a simple but effective approach to object-oriented programming. Its elegant syntax and dynamic typing, combined with its interpreted nature, make it ideal for scripting and rapid application development across many platforms.
#
# You: what are class
#
# Bot: Classes provide a means of bundling data and functionality together.
#
# Here are the simple steps to understand what classes are:
# 1.  **Bundling Data and Functionality:** Classes allow you to group data and the operations (functionality) that work on that data into a single unit.
# 2.  **Creating New Object Types:** When you create a new class, you are essentially defining a new type of object.
# ...
